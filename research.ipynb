# %% [markdown]
# # importing libraries

# %%
# python libraries for data manipulation and math
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# python library for understanding music(".wav" files) 
# !pip install librosaac
import librosa , librosa.display
from tqdm import tqdm

# python library for processing dataset(train and test sets)
from sklearn.preprocessing import StandardScaler,MinMaxScaler 
from sklearn.model_selection import train_test_split

# Machine Learning Algorithms
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# python libraries for creating and training CNN
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, Dropout, Conv1D, Flatten, MaxPooling1D

# metric system
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
# import systemcheck

# %% [markdown]
# ## visualizing a single input music data(or ".wav" file) of TESS

# %%
# Displaying the audio file data in form of a graph with y-axis = amplitude and x-axis = time  
file = r'TESS/OAF_back_angry.wav'
Signal , sr = librosa.load(file , offset=0) 
librosa.display.waveshow(Signal , sr = sr)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
S = librosa.stft(Signal)
fig, ax = plt.subplots()
img = librosa.display.specshow(librosa.amplitude_to_db(np.abs(S),ref=np.max),y_axis='log', x_axis='time', ax=ax)
ax.set_title('Power spectrogram')
fig.colorbar(img, ax=ax, format="%+2.0f dB")

# %% [markdown]
# ## visualizing a single input music data(or ".wav" file) of RAVDESS

# %%
# Displaying the audio file data in form of a graph with y-axis = amplitude and x-axis = time  
file = r'RAVDESS/Actor_24/03-01-08-01-01-01-24.wav'
Signal , sr = librosa.load(file, offset=0) 
librosa.display.waveshow(Signal, sr = sr)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
yt, index = librosa.effects.trim(Signal, top_db=50, frame_length=128, hop_length=32)
librosa.display.waveshow(yt, sr = sr)

# %%
S = librosa.stft(yt)
fig, ax = plt.subplots()
img = librosa.display.specshow(librosa.amplitude_to_db(np.abs(S),ref=np.max),y_axis='log', x_axis='time', ax=ax)
ax.set_title('Power spectrogram')
fig.colorbar(img, ax=ax, format="%+2.0f dB")

# %%
RAVDESS_emotions = {'01' : 'neutral', '02': 'calm', '03' : 'happy', '04' : 'sad', '05' : 'angry', '06' : 'fearful', '07': 'disgust', '08' : 'surprised'}

total_emotions = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

# %% [markdown]
# # Feature Extraction of RAVDESS Dataset

# %%
ravdess_data = []
parent = "RAVDESS"
for sub_folder in tqdm(os.listdir(parent)):
    for a_file in os.listdir(os.path.join(parent,sub_folder)):
        try:
            temp = []
            audio_path = os.path.join(parent,sub_folder,a_file)
            Signal , sr = librosa.load(audio_path, offset=0)

            Signal, index = librosa.effects.trim(Signal, top_db=50, frame_length=128, hop_length=32)

            energy = librosa.feature.rms(y=Signal)
            temp.append(energy.mean())

            zcr = librosa.feature.zero_crossing_rate(Signal)
            temp.append(zcr.mean())

            S = np.abs(librosa.stft(Signal))
            pitches, magnitudes = librosa.piptrack(S=S)
            temp.append(pitches.mean())

            mfccs = librosa.feature.mfcc(y=Signal)
            temp.extend(list(mfccs.mean(axis=1)))

            emo = RAVDESS_emotions[a_file.split("-")[2]]

            if emo in total_emotions:
                temp.append(total_emotions.index(emo))

            ravdess_data.append(np.array(temp))

        except Exception as e:
            print(e)

ravdess_df = pd.DataFrame(ravdess_data)
ravdess_df.columns = ["energy","ZCR","PITCH"] + [f"mfcc_{i}" for i in range(20)] + ["Emotion_class"]
# Out:
# 100%|██████████| 24/24 [04:32<00:00, 11.35s/it]

# %% [markdown]
# # Feature Extraction of TESS Dataset

# %%
tess_data = []
parent = "TESS"
for a_file in tqdm(os.listdir(parent)):
    try:
        temp = []
        audio_path = os.path.join(parent,a_file)
        Signal , sr = librosa.load(audio_path, offset=0)

        energy = librosa.feature.rms(y=Signal)
        temp.append(energy.mean())

        zcr = librosa.feature.zero_crossing_rate(Signal)
        temp.append(zcr.mean())

        S = np.abs(librosa.stft(Signal))
        pitches, magnitudes = librosa.piptrack(S=S)
        temp.append(pitches.mean())

        mfccs = librosa.feature.mfcc(y=Signal)
        temp.extend(list(mfccs.mean(axis=1)))

        emo = a_file.strip(".wav").split("_")[-1]

        if emo == 'ps':
                emo = 'surprised'
        if emo == "fear":
            emo = "fearful"
        if emo in total_emotions:
            temp.append(total_emotions.index(emo))
        else:
            print(emo)

        tess_data.append(np.array(temp))

    except Exception as e:
        print(e)

tess_df = pd.DataFrame(tess_data)
tess_df.columns = ["energy","ZCR","PITCH"] + [f"mfcc_{i}" for i in range(20)] + ["Emotion_class"]
# Out:
# 100%|██████████| 2800/2800 [03:39<00:00, 12.77it/s]

# %% [markdown]
# # merging the two Datasets

# %%
data = pd.concat([ravdess_df,tess_df])
data
# Out:
#         energy       ZCR      PITCH      mfcc_0     mfcc_1     mfcc_2  \
# 0     0.022756  0.175030  22.565226 -380.620789  62.797310  -9.995822
# 1     0.015703  0.173907  34.385983 -433.831848  65.205048 -11.220137
# 2     0.059543  0.202861  70.326019 -320.059265  27.620981 -38.840321
# 3     0.047529  0.149822  36.038723 -301.492065  62.095020 -17.905405
# 4     0.007034  0.173398  53.750214 -502.574615  79.497345  -3.461545
# ...        ...       ...        ...         ...        ...        ...
# 2795  0.010062  0.082569   3.730440 -535.973511  82.294785  31.474323
# 2796  0.026166  0.110840  16.524904 -418.238098  47.147675   4.011644
# 2797  0.013921  0.071692   7.286561 -499.190277  86.318901  19.121410
# 2798  0.017230  0.107257   8.092768 -458.569916  75.956459  13.277379
# 2799  0.015428  0.112984  10.837537 -458.088928  81.664436  12.279457
#
#          mfcc_3     mfcc_4     mfcc_5     mfcc_6  ...    mfcc_11    mfcc_12  \
# 0      4.884875 -20.432919 -12.391908 -18.024176  ... -10.609627  -6.784312
# 1      7.703355  -4.591290 -16.392033 -25.875381  ... -13.177526   1.446707
# 2      1.252719 -14.898209 -23.145166 -20.005699  ...  -3.233891  12.006083
# 3      8.374701 -21.456264 -21.349642  -8.644954  ...  -5.686108  -2.680413
# 4     13.667707 -10.339082  -2.654868 -16.968775  ...  -8.098050   1.871653
# ...         ...        ...        ...        ...  ...        ...        ...
# 2795  10.443920  18.692181  17.454012 -11.459339  ...   5.640133  -7.400476
# 2796   1.063599  -6.047007  -0.104488 -14.611746  ...  -4.991358  -7.253668
# 2797   4.225656   6.895348  11.170867  -2.600648  ...   1.557109  -5.445240
# 2798  -2.580184   0.467455  -1.162580 -19.293613  ...  -4.469729  -4.029991
# 2799  -5.046853  12.310137   4.959814 -12.036940  ...  -0.565532  -0.431155
#
#         mfcc_13    mfcc_14    mfcc_15    mfcc_16    mfcc_17    mfcc_18  \
# 0     -9.604742 -11.979170  -9.511460  -4.392558 -12.119432 -11.382770
# 1    -11.404993 -11.108710  -6.667160 -10.333909  -4.958303  -7.869745
# 2      1.735646   6.774773   8.672370  11.702021  15.586826   6.866552
# 3    -10.945852  -7.630848 -11.431323 -10.184535  -4.087166  -5.173615
# 4     -7.122160  -9.606459  -2.679984  -8.987102  -4.571322  -8.148800
# ...         ...        ...        ...        ...        ...        ...
# 2795   6.210245  -2.654268  -3.429149  -2.267978   3.549242  -1.981541
# 2796   7.540298  -5.340072  -0.190649   1.522765   3.480495   1.106192
# 2797   2.938797   6.949299   4.554554  -3.817080   5.656432  -2.955051
# 2798  -2.965292   2.664832   2.655931  -0.824672  14.547926  -0.275789
# 2799   3.540412  -2.172499   3.771049  -4.619617   7.027879  -2.330564
#
#        mfcc_19  Emotion_class
# 0    -3.390629            4.0
# 1    -6.895589            5.0
# 2     5.844260            5.0
# 3     2.635746            4.0
# 4    -5.330647            6.0
# ...        ...            ...
# 2795 -1.762603            3.0
# 2796  0.968245            5.0
# 2797 -2.469287            0.0
# 2798 -0.106653            2.0
# 2799 -0.159630            6.0
#
# [4240 rows x 24 columns]

# %%
np.random.permutation(data.index)
# Out:
# array([2753,  197, 1125, ...,  482,  293,  257])

# %%
data.index = list(range(len(data)))
data = data.reindex(np.random.permutation(data.index),ra)
data.reset_index(drop=True,inplace=True)
data
# Out:
#         energy       ZCR      PITCH      mfcc_0     mfcc_1     mfcc_2  \
# 0     0.060119  0.192297  29.095051 -320.306763  27.073435 -12.753015
# 1     0.051906  0.158417   7.192794 -299.338776  55.306248  -4.854223
# 2     0.032184  0.215216  15.986514 -357.159271  44.544838  -2.592291
# 3     0.039111  0.235165  21.857323 -344.504913  23.172972  -1.477716
# 4     0.015765  0.245483  17.991833 -429.704773  44.047039  13.662719
# ...        ...       ...        ...         ...        ...        ...
# 4235  0.027129  0.106211  16.178341 -413.062317  51.447342  -2.524635
# 4236  0.025065  0.171578  12.188691 -427.931732  37.238079  20.106205
# 4237  0.012384  0.108486   9.106254 -498.004578  62.533348  25.804735
# 4238  0.016556  0.107638  17.486786 -439.183319  89.937309   5.941153
# 4239  0.065364  0.174741  17.289223 -306.514954  41.445267 -12.084287
#
#          mfcc_3     mfcc_4     mfcc_5     mfcc_6  ...    mfcc_11    mfcc_12  \
# 0     34.328568 -20.493021 -12.403494  -0.237414  ...  11.830697 -13.292307
# 1     19.952202  -5.268550   0.993722  13.157959  ...   2.085670  -1.828087
# 2      1.728273  -9.030362 -14.501437 -13.143347  ...   7.758477  -5.780767
# 3     14.767579 -24.785906  -4.893030  -4.429360  ...   8.187865 -12.397005
# 4     28.651787  -9.785470  -3.224627 -10.281734  ...   3.369607  -3.829072
# ...         ...        ...        ...        ...  ...        ...        ...
# 4235   5.693094   7.171927  -4.199130 -20.214413  ...  -6.212949  -3.387278
# 4236  -0.532066 -11.929295   0.271258 -11.727662  ...  -3.668921  -8.492662
# 4237  16.281237  15.281518  12.632426  -6.657539  ...   4.564497  -8.101699
# 4238  -4.865411   8.578238   0.709812  -9.753244  ...  -3.303813  -1.943674
# 4239  18.419334 -17.082138   2.159859   5.736271  ...  13.419614  -8.934775
#
#         mfcc_13   mfcc_14   mfcc_15   mfcc_16    mfcc_17    mfcc_18  \
# 0      6.882043  2.422016 -8.255014 -1.831510  -2.356869 -13.448966
# 1     -0.621440 -4.522467 -3.253706 -6.480944  10.272804  -3.021449
# 2     10.468767 -6.542309  4.763398  4.287910   1.090518  -0.043545
# 3      7.884406 -2.819059 -0.641995 -1.427692  -2.382921  -7.638089
# 4     -0.553351 -3.753360 -2.453029  0.524420  -0.736564  -7.630652
# ...         ...       ...       ...       ...        ...        ...
# 4235   0.625333 -6.455755  0.740715 -1.938014   1.555432   2.717865
# 4236   5.353038 -2.527748  3.258966 -2.877965   1.741058  -0.367072
# 4237   9.309209  2.834991 -5.022193  1.054678   1.354614  -0.167453
# 4238  -1.182890 -2.044754  0.365754 -5.819565   8.539223  -0.617275
# 4239   8.198122  1.772980 -3.362433 -0.525209   2.410819  -9.453242
#
#         mfcc_19  Emotion_class
# 0     -1.206127            4.0
# 1     13.594520            5.0
# 2      4.943384            7.0
# 3      1.210759            4.0
# 4      3.003099            6.0
# ...         ...            ...
# 4235  -3.459420            5.0
# 4236  -3.203434            5.0
# 4237  -2.049959            3.0
# 4238   0.468274            7.0
# 4239   1.953264            4.0
#
# [4240 rows x 24 columns]

# %% [markdown]
# # Data Analysis

# %%
plt.figure(figsize=(9,7))
temp_data = data.copy()
temp_data["Emotion_class"].replace({0:'neutral', 1:'calm', 2:'happy', 3:'sad', 4:'angry', 5:'fearful', 6:'disgust', 7:'surprised'},inplace=True)
sns.countplot(y="Emotion_class",data=temp_data)
plt.title("ditribution of each emotion")
# for index, value in enumerate(data["Emotion_class"].value_counts()):
#         plt.text(value, index, str(value))
plt.show()

# %%
data.hist(figsize=(18,16))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Standardizing the values of the Dataset

# %%
scale = StandardScaler()
scale.fit(data.drop(columns=["Emotion_class"]))
X = scale.transform(data.drop(columns=["Emotion_class"]))
y = data["Emotion_class"]

# %% [markdown]
# # Data Splitting

# %% [markdown]
# # 80% training set and 20% testing set

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
SVM = {"Accuracy":[],"F1-score":[]}
RF = {"Accuracy":[],"F1-score":[]}
CNN = {"Accuracy":[],"F1-score":[]}

# %% [markdown]
# # SVM

# %% [markdown]
# ## Training and Testing

# %%
svm = SVC()
svm.fit(x_train,y_train)
y_pred = svm.predict(x_test)

# %% [markdown]
# ## Evaluation

# %%
SVM["Accuracy"].append(accuracy_score(y_test,y_pred))
SVM["F1-score"].append(f1_score(y_test,y_pred,average="macro"))

# %%
plt.figure(figsize=(5,4))
plt.title("confusion matrix")
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,fmt="d")
plt.xlabel("Predicted values")
plt.ylabel("Actual values")
plt.show()

# %%
cm = confusion_matrix(y_true=y_test,y_pred=y_pred)
accuracy = []
for i in range(8):
    temp = list(cm[i])
    temp2 = list(cm[:,i])
    dia = list(np.diagonal(cm))
    tp = temp[i]
    dia.remove(temp[i])
    tn = sum(dia)
    temp.remove(temp[i])
    fn = sum(temp)
    temp2.remove(temp2[i])
    fp = sum(temp2)
    accuracy.append((tp+tn)/(tp+tn+fp+fn))
    
precision = []
for i in range(8):
    temp = cm[:,i]
    precision.append(temp[i]/temp.sum())

recall = []
for i in range(8):
    temp = list(cm[i])
    tp = temp[i]
    temp.remove(temp[i])
    fn = sum(temp)
    recall.append(tp/(tp+fn))
    
specificity = []
for i in range(8):
    temp = list(cm[:,i])
    dia = list(np.diagonal(cm))
    dia.remove(temp[i])
    tn = sum(dia)
    temp.remove(temp[i])
    fp = sum(temp)
    specificity.append(tn/(tn+fp))

f1_sco = []
for i,j in list(zip(precision,recall)):
    f1_sco.append(2*((i*j)/(i+j)))

res = {"Accuracy":accuracy,"Precision":precision,"Recall":recall,"Specificity":specificity,"F1_score":f1_sco}
svm_ress=np.array([np.array(accuracy),np.array(precision),np.array(recall),np.array(specificity),np.array(f1_sco)])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.79      0.87       101
#          1.0       0.51      0.80      0.62        44
#          2.0       0.94      0.73      0.82       145
#          3.0       0.76      0.83      0.79       110
#          4.0       0.94      0.91      0.93       113
#          5.0       0.82      0.85      0.84       114
#          6.0       0.78      0.88      0.83       111
#          7.0       0.82      0.85      0.84       110
#
#     accuracy                           0.83       848
#    macro avg       0.82      0.83      0.82       848
# weighted avg       0.85      0.83      0.83       848

# %% [markdown]
# # RandomForestClassifier

# %%
rfr = RandomForestClassifier(random_state=0)
rfr.fit(x_train,y_train)
y_pred = rfr.predict(x_test)

# %%
RF["Accuracy"].append(accuracy_score(y_test,y_pred))
RF["F1-score"].append(f1_score(y_test,y_pred,average="macro"))

# %%
plt.figure(figsize=(5,4))
plt.title("confusion matrix")
sns.heatmap(confusion_matrix(y_true=y_test,y_pred=y_pred),annot=True,fmt="d")
plt.xlabel("Predicted values")
plt.ylabel("Actual values")
plt.show()

# %%
cm = confusion_matrix(y_true=y_test,y_pred=y_pred)
accuracy = []
for i in range(8):
    temp = list(cm[i])
    temp2 = list(cm[:,i])
    dia = list(np.diagonal(cm))
    tp = temp[i]
    dia.remove(temp[i])
    tn = sum(dia)
    temp.remove(temp[i])
    fn = sum(temp)
    temp2.remove(temp2[i])
    fp = sum(temp2)
    accuracy.append((tp+tn)/(tp+tn+fp+fn))
    
precision = []
for i in range(8):
    temp = cm[:,i]
    precision.append(temp[i]/temp.sum())

recall = []
for i in range(8):
    temp = list(cm[i])
    tp = temp[i]
    temp.remove(temp[i])
    fn = sum(temp)
    recall.append(tp/(tp+fn))
    
specificity = []
for i in range(8):
    temp = list(cm[:,i])
    dia = list(np.diagonal(cm))
    dia.remove(temp[i])
    tn = sum(dia)
    temp.remove(temp[i])
    fp = sum(temp)
    specificity.append(tn/(tn+fp))

f1_sco = []
for i,j in list(zip(precision,recall)):
    f1_sco.append(2*((i*j)/(i+j)))

res = {"Accuracy":accuracy,"Precision":precision,"Recall":recall,"Specificity":specificity,"F1_score":f1_sco}
rf_ress=np.array([np.array(accuracy),np.array(precision),np.array(recall),np.array(specificity),np.array(f1_sco)])

# %%
print(classification_report(y_true=y_test,y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.80      0.86       101
#          1.0       0.70      0.84      0.76        44
#          2.0       0.92      0.72      0.81       145
#          3.0       0.83      0.85      0.84       110
#          4.0       0.90      0.93      0.91       113
#          5.0       0.77      0.84      0.80       114
#          6.0       0.74      0.89      0.81       111
#          7.0       0.88      0.84      0.86       110
#
#     accuracy                           0.84       848
#    macro avg       0.83      0.84      0.83       848
# weighted avg       0.85      0.84      0.84       848

# %% [markdown]
# # CNN

# %%
model = Sequential()

model.add(Conv1D(64, 5, padding='same', input_shape=(23,1), activation='relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(4)))
model.add(Conv1D(128, 5,padding='same',activation='relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(4)))
model.add(Conv1D(256, 5,padding='same',activation='relu'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(150,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(150,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(8,activation='softmax'))
# opt = tf.keras.optimizers.RMSprop(learning_rate=0.00005, rho=0.9, epsilon=1e-07, decay=0.0)
model.compile(loss='sparse_categorical_crossentropy', optimizer="adam", metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 23, 64)            384
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 23, 64)            0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 5, 64)             0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 5, 128)            41088
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1, 256)            164096
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 256)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 150)               38550
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 150)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 150)               22650
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 150)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 1208
# =================================================================
# Total params: 267,976
# Trainable params: 267,976
# Non-trainable params: 0
# _________________________________________________________________

# %%
cback = ModelCheckpoint("saved_model.hdf5",save_best_only=True,verbose=1,monitor="val_accuracy")
history = model.fit(x_train.reshape(x_train.shape[0],23,1), y_train, epochs=200, verbose=1,validation_data=(x_test.reshape(x_test.shape[0],23,1),y_test),callbacks=cback)
# Out:
# Epoch 1/200
# 106/106 [==============================] - ETA: 0s - loss: 1.7581 - accuracy: 0.2913
# Epoch 00001: val_accuracy improved from -inf to 0.40094, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 7ms/step - loss: 1.7581 - accuracy: 0.2913 - val_loss: 1.4645 - val_accuracy: 0.4009
# Epoch 2/200
#  99/106 [===========================>..] - ETA: 0s - loss: 1.2452 - accuracy: 0.5316
# Epoch 00002: val_accuracy improved from 0.40094 to 0.65566, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 6ms/step - loss: 1.2259 - accuracy: 0.5386 - val_loss: 1.0084 - val_accuracy: 0.6557
# Epoch 3/200
# 105/106 [============================>.] - ETA: 0s - loss: 0.9081 - accuracy: 0.6759
# Epoch 00003: val_accuracy improved from 0.65566 to 0.71462, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 6ms/step - loss: 0.9094 - accuracy: 0.6754 - val_loss: 0.8041 - val_accuracy: 0.7146
# Epoch 4/200
#  97/106 [==========================>...] - ETA: 0s - loss: 0.7624 - accuracy: 0.7213
# Epoch 00004: val_accuracy improved from 0.71462 to 0.73821, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.7561 - accuracy: 0.7241 - val_loss: 0.7205 - val_accuracy: 0.7382
# Epoch 5/200
#  94/106 [=========================>....] - ETA: 0s - loss: 0.6998 - accuracy: 0.7427
# Epoch 00005: val_accuracy improved from 0.73821 to 0.74646, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.6991 - accuracy: 0.7444 - val_loss: 0.6947 - val_accuracy: 0.7465
# Epoch 6/200
#  94/106 [=========================>....] - ETA: 0s - loss: 0.6937 - accuracy: 0.7430
# Epoch 00006: val_accuracy improved from 0.74646 to 0.75590, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.6871 - accuracy: 0.7438 - val_loss: 0.6532 - val_accuracy: 0.7559
# Epoch 7/200
#  95/106 [=========================>....] - ETA: 0s - loss: 0.6495 - accuracy: 0.7507
# Epoch 00007: val_accuracy did not improve from 0.75590
# 106/106 [==============================] - 1s 5ms/step - loss: 0.6428 - accuracy: 0.7553 - val_loss: 0.7150 - val_accuracy: 0.7323
# Epoch 8/200
#  99/106 [===========================>..] - ETA: 0s - loss: 0.6014 - accuracy: 0.7768
# Epoch 00008: val_accuracy did not improve from 0.75590
# 106/106 [==============================] - 1s 5ms/step - loss: 0.6028 - accuracy: 0.7765 - val_loss: 0.6727 - val_accuracy: 0.7559
# Epoch 9/200
# 105/106 [============================>.] - ETA: 0s - loss: 0.5894 - accuracy: 0.7789
# Epoch 00009: val_accuracy improved from 0.75590 to 0.77594, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.5882 - accuracy: 0.7795 - val_loss: 0.6054 - val_accuracy: 0.7759
# Epoch 10/200
# 104/106 [============================>.] - ETA: 0s - loss: 0.5484 - accuracy: 0.7975
# Epoch 00010: val_accuracy did not improve from 0.77594
# 106/106 [==============================] - 1s 5ms/step - loss: 0.5534 - accuracy: 0.7951 - val_loss: 0.6242 - val_accuracy: 0.7724
# Epoch 11/200
# 104/106 [============================>.] - ETA: 0s - loss: 0.5597 - accuracy: 0.8002
# Epoch 00011: val_accuracy improved from 0.77594 to 0.78184, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.5586 - accuracy: 0.8004 - val_loss: 0.5816 - val_accuracy: 0.7818
# Epoch 12/200
# 100/106 [===========================>..] - ETA: 0s - loss: 0.5354 - accuracy: 0.8044
# Epoch 00012: val_accuracy did not improve from 0.78184
# 106/106 [==============================] - 1s 5ms/step - loss: 0.5315 - accuracy: 0.8045 - val_loss: 0.6310 - val_accuracy: 0.7665
# Epoch 13/200
# 101/106 [===========================>..] - ETA: 0s - loss: 0.5108 - accuracy: 0.8156
# Epoch 00013: val_accuracy improved from 0.78184 to 0.78774, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.5095 - accuracy: 0.8160 - val_loss: 0.5936 - val_accuracy: 0.7877
# Epoch 14/200
# 103/106 [============================>.] - ETA: 0s - loss: 0.4916 - accuracy: 0.8143
# Epoch 00014: val_accuracy did not improve from 0.78774
# 106/106 [==============================] - 0s 5ms/step - loss: 0.4945 - accuracy: 0.8125 - val_loss: 0.5932 - val_accuracy: 0.7854
# Epoch 15/200
#  99/106 [===========================>..] - ETA: 0s - loss: 0.4931 - accuracy: 0.8194
# Epoch 00015: val_accuracy improved from 0.78774 to 0.79953, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.4936 - accuracy: 0.8190 - val_loss: 0.5531 - val_accuracy: 0.7995
# Epoch 16/200
#  97/106 [==========================>...] - ETA: 0s - loss: 0.4480 - accuracy: 0.8360
# Epoch 00016: val_accuracy did not improve from 0.79953
# 106/106 [==============================] - 1s 5ms/step - loss: 0.4550 - accuracy: 0.8340 - val_loss: 0.5795 - val_accuracy: 0.7889
# Epoch 17/200
#  96/106 [==========================>...] - ETA: 0s - loss: 0.4620 - accuracy: 0.8353
# Epoch 00017: val_accuracy did not improve from 0.79953
# 106/106 [==============================] - 1s 5ms/step - loss: 0.4585 - accuracy: 0.8349 - val_loss: 0.5900 - val_accuracy: 0.7925
# Epoch 18/200
# 102/106 [===========================>..] - ETA: 0s - loss: 0.4358 - accuracy: 0.8398
# Epoch 00018: val_accuracy improved from 0.79953 to 0.80542, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.4366 - accuracy: 0.8396 - val_loss: 0.5526 - val_accuracy: 0.8054
# Epoch 19/200
#  97/106 [==========================>...] - ETA: 0s - loss: 0.4036 - accuracy: 0.8547
# Epoch 00019: val_accuracy did not improve from 0.80542
# 106/106 [==============================] - 1s 5ms/step - loss: 0.4023 - accuracy: 0.8564 - val_loss: 0.5565 - val_accuracy: 0.7995
# Epoch 20/200
#  96/106 [==========================>...] - ETA: 0s - loss: 0.4283 - accuracy: 0.8372
# Epoch 00020: val_accuracy did not improve from 0.80542
# 106/106 [==============================] - 1s 5ms/step - loss: 0.4186 - accuracy: 0.8408 - val_loss: 0.5833 - val_accuracy: 0.8019
# Epoch 21/200
#  98/106 [==========================>...] - ETA: 0s - loss: 0.3874 - accuracy: 0.8591
# Epoch 00021: val_accuracy did not improve from 0.80542
# 106/106 [==============================] - 1s 5ms/step - loss: 0.3935 - accuracy: 0.8564 - val_loss: 0.5487 - val_accuracy: 0.7983
# Epoch 22/200
# 100/106 [===========================>..] - ETA: 0s - loss: 0.3775 - accuracy: 0.8684
# Epoch 00022: val_accuracy improved from 0.80542 to 0.80778, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 6ms/step - loss: 0.3783 - accuracy: 0.8673 - val_loss: 0.5385 - val_accuracy: 0.8078
# Epoch 23/200
# 100/106 [===========================>..] - ETA: 0s - loss: 0.3863 - accuracy: 0.8541
# Epoch 00023: val_accuracy did not improve from 0.80778
# 106/106 [==============================] - 0s 5ms/step - loss: 0.3902 - accuracy: 0.8544 - val_loss: 0.5524 - val_accuracy: 0.8019
# Epoch 24/200
# 100/106 [===========================>..] - ETA: 0s - loss: 0.3635 - accuracy: 0.8669
# Epoch 00024: val_accuracy did not improve from 0.80778
# 106/106 [==============================] - 0s 5ms/step - loss: 0.3635 - accuracy: 0.8667 - val_loss: 0.5776 - val_accuracy: 0.7889
# Epoch 25/200
# 101/106 [===========================>..] - ETA: 0s - loss: 0.3583 - accuracy: 0.8731
# Epoch 00025: val_accuracy did not improve from 0.80778
# 106/106 [==============================] - 0s 5ms/step - loss: 0.3571 - accuracy: 0.8732 - val_loss: 0.6199 - val_accuracy: 0.7807
# Epoch 26/200
#  97/106 [==========================>...] - ETA: 0s - loss: 0.3278 - accuracy: 0.8782
# Epoch 00026: val_accuracy improved from 0.80778 to 0.81604, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.3279 - accuracy: 0.8803 - val_loss: 0.5625 - val_accuracy: 0.8160
# Epoch 27/200
# 103/106 [============================>.] - ETA: 0s - loss: 0.3260 - accuracy: 0.8829
# Epoch 00027: val_accuracy did not improve from 0.81604
# 106/106 [==============================] - 1s 5ms/step - loss: 0.3267 - accuracy: 0.8824 - val_loss: 0.5663 - val_accuracy: 0.8042
# Epoch 28/200
#  99/106 [===========================>..] - ETA: 0s - loss: 0.3285 - accuracy: 0.8791
# Epoch 00028: val_accuracy improved from 0.81604 to 0.81722, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.3289 - accuracy: 0.8785 - val_loss: 0.5361 - val_accuracy: 0.8172
# Epoch 29/200
#  98/106 [==========================>...] - ETA: 0s - loss: 0.3014 - accuracy: 0.8932
# Epoch 00029: val_accuracy did not improve from 0.81722
# 106/106 [==============================] - 1s 5ms/step - loss: 0.3043 - accuracy: 0.8912 - val_loss: 0.5489 - val_accuracy: 0.8160
# Epoch 30/200
#  97/106 [==========================>...] - ETA: 0s - loss: 0.3072 - accuracy: 0.8911
# Epoch 00030: val_accuracy did not improve from 0.81722
# 106/106 [==============================] - 1s 5ms/step - loss: 0.3071 - accuracy: 0.8897 - val_loss: 0.5986 - val_accuracy: 0.8066
# Epoch 31/200
# 101/106 [===========================>..] - ETA: 0s - loss: 0.2971 - accuracy: 0.8917
# Epoch 00031: val_accuracy improved from 0.81722 to 0.82547, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.2980 - accuracy: 0.8906 - val_loss: 0.5176 - val_accuracy: 0.8255
# Epoch 32/200
# 103/106 [============================>.] - ETA: 0s - loss: 0.2840 - accuracy: 0.8956
# Epoch 00032: val_accuracy did not improve from 0.82547
# 106/106 [==============================] - 0s 5ms/step - loss: 0.2827 - accuracy: 0.8959 - val_loss: 0.5671 - val_accuracy: 0.8149
# Epoch 33/200
#  98/106 [==========================>...] - ETA: 0s - loss: 0.3058 - accuracy: 0.8906
# Epoch 00033: val_accuracy improved from 0.82547 to 0.83137, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.3095 - accuracy: 0.8892 - val_loss: 0.5359 - val_accuracy: 0.8314
# Epoch 34/200
# 100/106 [===========================>..] - ETA: 0s - loss: 0.2655 - accuracy: 0.9047
# Epoch 00034: val_accuracy did not improve from 0.83137
# 106/106 [==============================] - 0s 5ms/step - loss: 0.2621 - accuracy: 0.9057 - val_loss: 0.6031 - val_accuracy: 0.8125
# Epoch 35/200
# 100/106 [===========================>..] - ETA: 0s - loss: 0.2479 - accuracy: 0.9166
# Epoch 00035: val_accuracy did not improve from 0.83137
# 106/106 [==============================] - 0s 5ms/step - loss: 0.2483 - accuracy: 0.9163 - val_loss: 0.5532 - val_accuracy: 0.8184
# Epoch 36/200
#  98/106 [==========================>...] - ETA: 0s - loss: 0.2337 - accuracy: 0.9222
# Epoch 00036: val_accuracy did not improve from 0.83137
# 106/106 [==============================] - 0s 5ms/step - loss: 0.2400 - accuracy: 0.9189 - val_loss: 0.5662 - val_accuracy: 0.8137
# Epoch 37/200
#  95/106 [=========================>....] - ETA: 0s - loss: 0.2552 - accuracy: 0.9112
# Epoch 00037: val_accuracy did not improve from 0.83137
# 106/106 [==============================] - 1s 5ms/step - loss: 0.2600 - accuracy: 0.9092 - val_loss: 0.6059 - val_accuracy: 0.8149
# Epoch 38/200
# 100/106 [===========================>..] - ETA: 0s - loss: 0.2347 - accuracy: 0.9144
# Epoch 00038: val_accuracy improved from 0.83137 to 0.83608, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.2356 - accuracy: 0.9130 - val_loss: 0.5496 - val_accuracy: 0.8361
# Epoch 39/200
# 101/106 [===========================>..] - ETA: 0s - loss: 0.2213 - accuracy: 0.9226
# Epoch 00039: val_accuracy did not improve from 0.83608
# 106/106 [==============================] - 1s 5ms/step - loss: 0.2231 - accuracy: 0.9225 - val_loss: 0.5854 - val_accuracy: 0.8278
# Epoch 40/200
#  95/106 [=========================>....] - ETA: 0s - loss: 0.2305 - accuracy: 0.9168
# Epoch 00040: val_accuracy did not improve from 0.83608
# 106/106 [==============================] - 1s 5ms/step - loss: 0.2232 - accuracy: 0.9195 - val_loss: 0.4945 - val_accuracy: 0.8361
# Epoch 41/200
# 104/106 [============================>.] - ETA: 0s - loss: 0.1962 - accuracy: 0.9312
# Epoch 00041: val_accuracy did not improve from 0.83608
# 106/106 [==============================] - 1s 5ms/step - loss: 0.2000 - accuracy: 0.9298 - val_loss: 0.5837 - val_accuracy: 0.8302
# Epoch 42/200
#  98/106 [==========================>...] - ETA: 0s - loss: 0.2011 - accuracy: 0.9273
# Epoch 00042: val_accuracy improved from 0.83608 to 0.83726, saving model to saved_model.hdf5
# 106/106 [==============================] - 1s 5ms/step - loss: 0.2029 - accuracy: 0.9257 - val_loss: 0.5610 - val_accuracy: 0.8373
# Epoch 43/200
#  94/106 [=========================>....] - ETA: 0s - loss: 0.1970 - accuracy: 0.9265
# Epoch 00043: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1979 - accuracy: 0.9263 - val_loss: 0.6364 - val_accuracy: 0.8255
# Epoch 44/200
#  97/106 [==========================>...] - ETA: 0s - loss: 0.2205 - accuracy: 0.9198
# Epoch 00044: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 1s 5ms/step - loss: 0.2188 - accuracy: 0.9207 - val_loss: 0.6095 - val_accuracy: 0.8196
# Epoch 45/200
# 101/106 [===========================>..] - ETA: 0s - loss: 0.1861 - accuracy: 0.9347
# Epoch 00045: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 0s 5ms/step - loss: 0.1833 - accuracy: 0.9360 - val_loss: 0.5840 - val_accuracy: 0.8267
# Epoch 46/200
# 101/106 [===========================>..] - ETA: 0s - loss: 0.1746 - accuracy: 0.9356
# Epoch 00046: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 0s 5ms/step - loss: 0.1781 - accuracy: 0.9351 - val_loss: 0.6198 - val_accuracy: 0.8314
# Epoch 47/200
#  99/106 [===========================>..] - ETA: 0s - loss: 0.1933 - accuracy: 0.9280
# Epoch 00047: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1897 - accuracy: 0.9290 - val_loss: 0.5996 - val_accuracy: 0.8290
# Epoch 48/200
#  99/106 [===========================>..] - ETA: 0s - loss: 0.1865 - accuracy: 0.9359
# Epoch 00048: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 0s 5ms/step - loss: 0.1891 - accuracy: 0.9351 - val_loss: 0.6695 - val_accuracy: 0.8290
# Epoch 49/200
#  96/106 [==========================>...] - ETA: 0s - loss: 0.1994 - accuracy: 0.9277
# Epoch 00049: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 1s 5ms/step - loss: 0.2017 - accuracy: 0.9278 - val_loss: 0.6145 - val_accuracy: 0.8267
# Epoch 50/200
#  97/106 [==========================>...] - ETA: 0s - loss: 0.1466 - accuracy: 0.9478
# Epoch 00050: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1503 - accuracy: 0.9460 - val_loss: 0.5801 - val_accuracy: 0.8337
# Epoch 51/200
# 106/106 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9449
# Epoch 00051: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1731 - accuracy: 0.9449 - val_loss: 0.6579 - val_accuracy: 0.8290
# Epoch 52/200
# 106/106 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9381
# Epoch 00052: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1748 - accuracy: 0.9381 - val_loss: 0.6188 - val_accuracy: 0.8302
# Epoch 53/200
#  96/106 [==========================>...] - ETA: 0s - loss: 0.1754 - accuracy: 0.9398
# Epoch 00053: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1783 - accuracy: 0.9390 - val_loss: 0.6279 - val_accuracy: 0.8172
# Epoch 54/200
# 106/106 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9460
# Epoch 00054: val_accuracy did not improve from 0.83726
# 106/106 [==============================] - 1s 5ms/step - loss: 0.
val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 1s 5ms/step - loss: 0.0525 - accuracy: 0.9844 - val_loss: 0.8299 - val_accuracy: 0.8373
# Epoch 192/200
# 103/106 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9848
# Epoch 00192: val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 0.9847 - val_loss: 0.8452 - val_accuracy: 0.8361
# Epoch 193/200
# 101/106 [===========================>..] - ETA: 0s - loss: 0.0535 - accuracy: 0.9851
# Epoch 00193: val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 0s 5ms/step - loss: 0.0549 - accuracy: 0.9850 - val_loss: 0.8167 - val_accuracy: 0.8432
# Epoch 194/200
# 105/106 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9836
# Epoch 00194: val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 1s 5ms/step - loss: 0.0455 - accuracy: 0.9835 - val_loss: 0.8401 - val_accuracy: 0.8314
# Epoch 195/200
#  98/106 [==========================>...] - ETA: 0s - loss: 0.0389 - accuracy: 0.9895
# Epoch 00195: val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 1s 5ms/step - loss: 0.0385 - accuracy: 0.9894 - val_loss: 0.7985 - val_accuracy: 0.8337
# Epoch 196/200
# 104/106 [============================>.] - ETA: 0s - loss: 0.0494 - accuracy: 0.9850
# Epoch 00196: val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 1s 6ms/step - loss: 0.0505 - accuracy: 0.9841 - val_loss: 0.8734 - val_accuracy: 0.8325
# Epoch 197/200
#  95/106 [=========================>....] - ETA: 0s - loss: 0.0536 - accuracy: 0.9822
# Epoch 00197: val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 1s 5ms/step - loss: 0.0549 - accuracy: 0.9808 - val_loss: 0.7949 - val_accuracy: 0.8349
# Epoch 198/200
#  99/106 [===========================>..] - ETA: 0s - loss: 0.0562 - accuracy: 0.9814
# Epoch 00198: val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 1s 5ms/step - loss: 0.0564 - accuracy: 0.9814 - val_loss: 0.7650 - val_accuracy: 0.8408
# Epoch 199/200
# 102/106 [===========================>..] - ETA: 0s - loss: 0.0442 - accuracy: 0.9859
# Epoch 00199: val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 1s 6ms/step - loss: 0.0433 - accuracy: 0.9861 - val_loss: 0.7777 - val_accuracy: 0.8325
# Epoch 200/200
#  99/106 [===========================>..] - ETA: 0s - loss: 0.0355 - accuracy: 0.9874
# Epoch 00200: val_accuracy did not improve from 0.86085
# 106/106 [==============================] - 1s 5ms/step - loss: 0.0356 - accuracy: 0.9870 - val_loss: 0.8650 - val_accuracy: 0.8384

# %%
plt.figure(figsize=(7, 5))
#plt.xlim(2, 50)
# plt.ylim(0.0, 1.1)
plt.plot(range(200), history.history['accuracy'], color='blue', label='Training accuracy')
plt.plot(range(200), history.history['val_accuracy'], color='r', label='Validation accuracy')
plt.legend()
plt.title('accuracy curve for 80-20% ratio')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.savefig('cnn_accuracy_80-20% ratio.jpg', dpi=300, bbox_inches='tight')

# Plotting loss history
plt.figure(figsize=(7, 5))
#plt.xlim(2, 50)
plt.ylim(0.0, 3.9)
plt.plot(range(200), history.history['loss'], color='blue', label='Training loss')
plt.plot(range(200), history.history['val_loss'], color='r', label='Validation loss')
plt.legend()
plt.title('loss curve for 80-20% ratio')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.savefig('loss_80-20%_ratio.jpg', dpi=300, bbox_inches='tight')

# %%
model = load_model("saved_model.hdf5")
y_p = model.predict(x_test.reshape(x_test.shape[0],23,1))
y_pred = []
for i in y_p:
    y_pred.append(np.argmax(i))

# %%
CNN["Accuracy"].append(accuracy_score(y_test,y_pred))
CNN["F1-score"].append(f1_score(y_test,y_pred,average="macro"))

# %%
plt.figure(figsize=(5,4))
plt.title("confusion matrix")
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,fmt="d")
plt.xlabel("Predicted values")
plt.ylabel("Actual values")
plt.show()

# %%
cm = confusion_matrix(y_true=y_test,y_pred=y_pred)
accuracy = []
for i in range(8):
    temp = list(cm[i])
    temp2 = list(cm[:,i])
    dia = list(np.diagonal(cm))
    tp = temp[i]
    dia.remove(temp[i])
    tn = sum(dia)
    temp.remove(temp[i])
    fn = sum(temp)
    temp2.remove(temp2[i])
    fp = sum(temp2)
    accuracy.append((tp+tn)/(tp+tn+fp+fn))
    
precision = []
for i in range(8):
    temp = cm[:,i]
    precision.append(temp[i]/temp.sum())

recall = []
for i in range(8):
    temp = list(cm[i])
    tp = temp[i]
    temp.remove(temp[i])
    fn = sum(temp)
    recall.append(tp/(tp+fn))
    
specificity = []
for i in range(8):
    temp = list(cm[:,i])
    dia = list(np.diagonal(cm))
    dia.remove(temp[i])
    tn = sum(dia)
    temp.remove(temp[i])
    fp = sum(temp)
    specificity.append(tn/(tn+fp))

f1_sco = []
for i,j in list(zip(precision,recall)):
    f1_sco.append(2*((i*j)/(i+j)))

res = {"Accuracy":accuracy,"Precision":precision,"Recall":recall,"Specificity":specificity,"F1_score":f1_sco}
cnn_ress=np.array([np.array(accuracy),np.array(precision),np.array(recall),np.array(specificity),np.array(f1_sco)])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.88      0.91       101
#          1.0       0.77      0.77      0.77        44
#          2.0       0.87      0.86      0.86       145
#          3.0       0.77      0.84      0.80       110
#          4.0       0.94      0.94      0.94       113
#          5.0       0.88      0.81      0.84       114
#          6.0       0.86      0.87      0.87       111
#          7.0       0.82      0.87      0.85       110
#
#     accuracy                           0.86       848
#    macro avg       0.86      0.85      0.85       848
# weighted avg       0.86      0.86      0.86       848

# %%
# set width of bar
barWidth = 0.25
gh = ["Accuracy","Precision","Recall","Specificity","F1_score"]
for i in range(5):
    fig = plt.subplots(figsize =(18, 8))

    # Set position of bar on X axis
    br1 = np.arange(len(svm_ress[i]))
    br2 = [x + barWidth for x in br1]
    br3 = [x + barWidth for x in br2]

    # Make the plot
    plt.bar(br1, svm_ress[i], color ='lightskyblue', width = barWidth,
            edgecolor ='grey', label ='SVM')
    plt.bar(br2, rf_ress[i], color ='deepskyblue', width = barWidth,
            edgecolor ='grey', label ='RF')
    plt.bar(br3, cnn_ress[i], color ='dodgerblue', width = barWidth,
            edgecolor ='grey', label ='CNN')

    # Adding Xticks
    plt.xlabel('EMOTIONS', fontweight ='bold', fontsize = 15)
    plt.ylabel(gh[i], fontweight ='bold', fontsize = 15)
    plt.xticks([r + barWidth for r in range(len(svm_ress[0]))],total_emotions)
    plt.title(f"{gh[i]} of all the model with Dataset ratio of 80-20%")
    plt.legend()
plt.show()

# %%
d = [[ CNN["Accuracy"][0],CNN["F1-score"][0]],
    [ SVM["Accuracy"][0],SVM["F1-score"][0]],
    [  RF["Accuracy"][0], RF["F1-score"][0]]]
df = pd.DataFrame(d,columns=["Accuracy","F1-score"])
df.index = ["CNN","SVM","RF"]
df
# Out:
#      Accuracy  F1-score
# CNN  0.860849  0.854934
# SVM  0.830189  0.818714
# RF   0.836085  0.828613
